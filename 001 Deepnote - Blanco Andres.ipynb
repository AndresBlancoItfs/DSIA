# %% [markdown]
# # TP01 \- Deepnote Blanco Andrés

# %%
input_1 = 'Mi nombre es Andrés Blanco, actualmente estoy trabajando en integracion de datos y reporteria en el departamento de Tarjetas de la gerencia de Medios de Pago en el Banco Provincia. Espero poder obtener nuevos conocimientos para implementar en mi trabajo actual.'

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aa80d3a7-2242-4311-b99f-5cc768f0a0d4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
