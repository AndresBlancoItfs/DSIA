# %% [markdown]
# # TP03 – Python Librerías

# %%
input_1 = 'Andrés Blanco'

# %% [markdown]
# ### Ejercicio 1 – Importación de librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datos = np.array([10, 20, 30, 40, 50])
print(datos)
# Out:
# [10 20 30 40 50]

# %%
import pandas as pd

# Crear un diccionario con los datos
data = {
    'estudiante': ['Ana', 'Juan', 'Carla', 'Pedro', 'Lucia'],
    'nota': [8, 6, 9, 5, 7]
}

df = pd.DataFrame(data)

# %%
# 1. Datos del DataFrame
print("DataFrame completo:")
print(df)

# 2. Promedio de las notas
promedio = df['nota'].mean()
print("\nPromedio de las notas:", promedio)

# 3. Nota máxima
maxima = df['nota'].max()
print("Nota máxima:", maxima)

# 4. Nota mínima
minima = df['nota'].min()
print("Nota mínima:", minima)
# Out:
# DataFrame completo:
#   estudiante  nota
# 0        Ana     8
# 1       Juan     6
# 2      Carla     9
# 3      Pedro     5
# 4      Lucia     7
#
# Promedio de las notas: 7.0
# Nota máxima: 9
# Nota mínima: 5

# %% [markdown]
# ### Ejercicio 3 – Criterio de selección de herramientas

# %%
input_2 = '1. pandas                          ---> porque permite cargar y manipular datos tabulares desde archivos CSV mediante funciones como read_csv().                                                                                                                                                               2. seaborn (o matplotlib) ---> porque ofrece herramientas sencillas y optimizadas para graficar distribuciones estadísticas, como histogramas.                                                                                                                                      3. scikit-learn                   ---> porque contiene algoritmos preconstruidos y herramientas estándar para crear y evaluar modelos de Machine Learning.                                                                                                                                         4. numpy                          ---> porque está especializada en el manejo eficiente de arreglos multidimensionales y operaciones matemáticas matriciales.'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aa80d3a7-2242-4311-b99f-5cc768f0a0d4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
